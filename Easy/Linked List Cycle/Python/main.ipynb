# %% [markdown]
# # Linked List Cycle

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()
li = _.ListNode

# %% [markdown]
# ## Test 1

# %%
node = li(2)
task.hasCycle(head = li(3).add(node).add([0, -4]).add(node))
# Out:
# True

# %% [markdown]
# ## Test 2

# %%
node = li(1)
task.hasCycle(head = node.add(2).add(node))
# Out:
# True

# %% [markdown]
# ## Test 3

# %%
task.hasCycle(head = li([1]))
# Out:
# False
