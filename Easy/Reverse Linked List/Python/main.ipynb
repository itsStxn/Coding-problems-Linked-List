# %% [markdown]
# # Reverse Linked List

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()
li = _.ListNode

# %% [markdown]
# ## Test 1

# %%
task.reverseList(head = li([1,2,3,4,5]))
# Out:
# 5, 4, 3, 2, 1

# %% [markdown]
# ## Test 2

# %%
task.reverseList(head = li([1,2]))
# Out:
# 2, 1

# %% [markdown]
# ## Test 3

# %%
task.reverseList(head = None)
