# %% [markdown]
# # Find the Duplicate Number

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.findDuplicate(nums = [1,3,4,2,2])
# Out:
# 2

# %% [markdown]
# ## Test 2

# %%
task.findDuplicate(nums = [3,1,3,4,2])
# Out:
# 3

# %% [markdown]
# ## Test 3

# %%
task.findDuplicate(nums = [3,3,3,3,3])
# Out:
# 3
