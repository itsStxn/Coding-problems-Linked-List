# %% [markdown]
# # LRU Cache

# %%
import importlib
import solution as _

importlib.reload(_)
lRUCache = _.LRUCache(2)

# %% [markdown]
# ## Test 1

# %%
lRUCache.put(1, 1)
lRUCache.put(2, 2) 
lRUCache.get(1);   
lRUCache.put(3, 3) 
lRUCache.get(2)  
lRUCache.put(4, 4) 
lRUCache.get(1)  
lRUCache.get(3)    
lRUCache.get(4)
# Out:
# cache is {1=1}
# cache is {2=2, 1=1}
# return 1
# cache is {3=3, 1=1}
# returns -1 (not found)
# cache is {4=4, 3=3}
# returns -1 (not found)
# return 3
# return 4
# 4
