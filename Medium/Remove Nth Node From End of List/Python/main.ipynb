# %% [markdown]
# # Remove Nth Node From End of List

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()
li = _.ListNode

# %% [markdown]
# ## Test 1

# %%
task.removeNthFromEnd(head = li([1,2,3,4,5]), n = 2)
# Out:
# 1, 2, 3, 5

# %% [markdown]
# ## Test 2

# %%
task.removeNthFromEnd(head = li([1]), n = 1)

# %% [markdown]
# ## Test 3

# %%
task.removeNthFromEnd(head = li([1,2]), n = 1)
# Out:
# 1
