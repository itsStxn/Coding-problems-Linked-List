# %% [markdown]
# # Reorder List

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()
li = _.ListNode

# %% [markdown]
# ## Test 1

# %%
head = li([1,2,3,4])
task.reorderList(head)
head
# Out:
# 1, 4, 2, 3

# %% [markdown]
# ## Test 2

# %%
head = li([1,2,3,4,5])
task.reorderList(head)
head
# Out:
# 1, 5, 2, 4, 3
