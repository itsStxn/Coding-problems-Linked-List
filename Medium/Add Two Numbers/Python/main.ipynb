# %% [markdown]
# # Add Two Numbers

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()
li = _.ListNode

# %% [markdown]
# ## Test 1

# %%
task.addTwoNumbers(l1 = li([2,4,3]), l2 = li([5,6,4]))
# Out:
# 7, 0, 8

# %% [markdown]
# ## Test 2

# %%
task.addTwoNumbers(l1 = li([0]), l2 = li([0]))
# Out:
# 0

# %% [markdown]
# ## Test 3

# %%
task.addTwoNumbers(l1 = li([9,9,9,9,9,9,9]), l2 = li([9,9,9,9]))
# Out:
# 8, 9, 9, 9, 0, 0, 0, 1
