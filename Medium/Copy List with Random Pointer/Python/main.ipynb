# %% [markdown]
# # Copy List with Random Pointer

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()
n = _.Node

# %% [markdown]
# ## Test 1

# %%
from typing import cast


node1 = n(x=7)
node2 = n(x=13)
node3 = n(x=11)
node4 = n(x=10)
node5 = n(x=1)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

node2.random = node1
node3.random = node5
node4.random = node3
node5.random = node1

task.copyRandomList(head=node1)
# Out:
# 7, 13, 11, 10, 1

# %% [markdown]
# ## Test 2

# %%
node1 = n(x=1)
node2 = n(x=2)

node1.next = node2

node1.random = node2
node2.random = node2

task.copyRandomList(head=node1)
# Out:
# 1, 2

# %% [markdown]
# ## Test 3

# %%
node1 = n(x=3)
node2 = n(x=3)
node3 = n(x=3)

node1.next = node2
node2.next = node3

node2.random = node1

task.copyRandomList(head=node1)
# Out:
# 3, 3, 3
